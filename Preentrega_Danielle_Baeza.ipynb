# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielleFuenzalida/Proyecto-1-Pre-entrega-1/blob/main/Preentrega_Danielle_Baeza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Datos

# %%
df= pd.read_excel('/content/drive/MyDrive/curso/StudentPerformanceFactors.xls')
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.head(20)
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23          84                  Low                High
# 1              19          64                  Low              Medium
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 4              19          92               Medium              Medium
# 5              19          88               Medium              Medium
# 6              29          84               Medium                 Low
# 7              25          78                  Low                High
# 8              17          94               Medium                High
# 9              23          98               Medium              Medium
# 10             17          80                  Low                High
# 11             17          97               Medium                High
# ...

# %% [markdown]
# # Preguntas para analizar y predecir
#
# ¿Cuantas horas es recomendable dormir para un buen desempeño académico ?
#
# ¿Cuántas horas de estudios es beneficios para una calificación sobre 70% ?
#
# ¿Influye en la motivación de los estudiantes en la calidad de los profesores y el tipo de establecimiento?
#
# ¿Vivir cerca o lejos de la escual influye en el porcentaje de asistencia a clases ?
#
# Calificación en exámenes entre hombres y mujeres
#
# Acceso a internet, hacer actividades extracurriculares, tutorías y recursos educativos ¿fueron influyentes en la calificaciones de los exámenes anteriores ??

# %% [markdown]
# # ¿Cuántas horas es recomendable dormir para un buen desempeño acádemico?

# %%
if 'Sleep_Hours' in df.columns and 'Exam_Score' in df.columns: # Changed 'data' to 'df'
    sleep_hours = df['Sleep_Hours'] # Changed 'data' to 'df'
    exam_score = df['Exam_Score'] # Changed 'data' to 'df'

    # Crear el gráfico de dispersión
    plt.figure(figsize=(8, 6))
    plt.scatter(sleep_hours, exam_score, color='purple', alpha=0.6)
    plt.title('Relación entre Horas de Sueño y Puntaje del Examen', fontsize=14, fontweight='bold')
    plt.xlabel('Horas de Sueño', fontsize=12)
    plt.ylabel('Puntaje del Examen', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)

    # Ajustar límites para mayor claridad si es necesario
    plt.xlim(df['Sleep_Hours'].min() - 1, df['Sleep_Hours'].max() + 1) # Changed 'data' to 'df'
    plt.ylim(df['Exam_Score'].min() - 5, df['Exam_Score'].max() + 5) # Changed 'data' to 'df'

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# # ¿Cuántas horas de estudios es beneficios para una calificación sobre 70% ?

# %%
# Crear el gráfico de dispersión
plt.figure(figsize=(8, 6))

# Extracting the 'Study_Hours' column from the DataFrame 'df' and assigning it to the variable 'Hours_Studied'.
# Assuming 'Study_Hours' is the correct column name in your DataFrame.
# If the column name is different, replace 'Study_Hours' with the actual column name.
Hours_Studied = df['Hours_Studied']

plt.scatter(Hours_Studied, exam_score, color='blue', alpha=0.6, edgecolor='k')
plt.title('Relación entre Horas de Estudio y Puntaje del Examen', fontsize=14, fontweight='bold')
plt.xlabel('Horas de Estudio', fontsize=12)
plt.ylabel('Puntaje del Examen', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)

#Ajustar límites para mayor claridad si es necesario.
# Make sure you are referencing the correct columns and DataFrame ('df') in the xlim and ylim functions.
plt.xlim(df['Hours_Studied'].min() - 1, df['Hours_Studied'].max() + 1)
plt.ylim(df['Exam_Score'].min() - 5, df['Exam_Score'].max() + 5)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # ¿Influye en la motivación de los estudiantes en la calidad de los profesores y el tipo de establecimiento?

# %%
import seaborn as sns

# Carga tus datos (asegúrate de tener los datos en df)
# df = pd.read_csv("ruta_a_tus_datos.csv")

# Ajusta el estilo de los gráficos
sns.set(style="whitegrid")

# Crea el gráfico de barras agrupadas para mostrar la relación entre Teacher_Quality, School_Type y Motivation_Level
plt.figure(figsize=(12, 6))
sns.barplot(x="School_Type", y="Teacher_Quality", hue="Motivation_Level", data=df)

# Agrega títulos y etiquetas
plt.title("Relación entre Calidad de Profesores, Tipo de Establecimiento y Nivel de Motivación", fontsize=10)
plt.xlabel("Tipo de Establecimiento", fontsize=10)
plt.ylabel("Calidad de Profesores", fontsize=10)

# Muestra el gráfico
plt.legend(title='Nivel de Motivación')
plt.show()

# %% [markdown]
# # ¿Vivir cerca o lejos de la escuela influyen en el porcentaje de asistencia a clases ?

# %%
plt.figure(figsize=(8, 6))
if 'Distance_from_Home' in df.columns and 'Attendance' in df.columns:
    # Changed x and y to the actual column names in the dataframe
    sns.scatterplot(x='Distance_from_Home', y='Attendance', data=df)

# %% [markdown]
# #Calificación en exámenes entre hombres y mujeres

# %%
# Crea un gráfico de cajas para mostrar la distribución de Exam_Score por género
plt.figure(figsize=(10, 6))
sns.boxplot(x="Gender", y="Exam_Score", data=df)

# Agrega títulos y etiquetas
plt.title("Puntuaciones de Examen por Género", fontsize=16)
plt.xlabel("Género", fontsize=14)
plt.ylabel("Puntuación del Examen", fontsize=14)

# Muestra el gráfico
plt.show()

# %% [markdown]
# # Acceso a internet, hacer actividades extracurriculares, tutorías y recursos educativos ¿fueron influyentes en la calificaciones de los exámenes anteriores ?

# %%
# Importa las bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carga tus datos (asegúrate de tener los datos en df)
# df = pd.read_csv("ruta_a_tus_datos.csv")

# Ajusta el estilo de los gráficos
sns.set(style="whitegrid")

# Define las variables que quieres graficar contra Exam_Score
variables = ['Internet_Access', 'Extracurricular_Activities', 'Tutoring_Sessions', 'Access_to_Resources']

# Configura el gráfico
plt.figure(figsize=(14, 10))

# Crear un gráfico de violín para cada una de las variables
for i, var in enumerate(variables, 1):
    plt.subplot(2, 2, i)  # Crear subgráficos (2 filas, 2 columnas)
    sns.violinplot(x=var, y="Exam_Score", data=df)
    plt.title(f"Relación entre {var} y Puntuación del Examen", fontsize=12)
    plt.xlabel(var, fontsize=10)
    plt.ylabel("Puntuación del Examen", fontsize=10)

# Ajusta el diseño y muestra el gráfico
plt.tight_layout()
plt.show()

# %%
# Función para calcular el porcentaje de outliers basado en el criterio de 1.5 IQR
def calculate_outliers(df):
    outliers_percentage = {}
    numeric_columns = df.select_dtypes(include=['number']).columns

    for col in numeric_columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_percentage = 100 * len(outliers) / len(df)

        # Solo guardar si el porcentaje de outliers es mayor a cero
        if outlier_percentage > 0:
            outliers_percentage[col] = outlier_percentage

    # Convertir a DataFrame
    return pd.DataFrame.from_dict(outliers_percentage, orient='index', columns=['Outliers (%)']).sort_values(by='Outliers (%)', ascending=False)

# Aplicar la función y mostrar el porcentaje de outliers
calculate_outliers(df)
# Out:
#                    Outliers (%)
# Tutoring_Sessions      6.508249
# Exam_Score             1.574088
# Hours_Studied          0.650825
